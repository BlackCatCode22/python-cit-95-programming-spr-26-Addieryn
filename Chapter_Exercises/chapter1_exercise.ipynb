# %% [markdown]
# ## Chapter 1 Exercises

# %% [markdown]
# #### Exercise 1: What is the function of the secondary memory in a computer?
#
# - a) Execute all of the computation and logic of the program
# - b) Retrieve web pages over the Internet
# - c) Store information for the long term, even beyond a power cycle
# - d) Take input from the user

# %% [markdown]
# c) Store information for the long term, even beyond a power cycle

# %% [markdown]
# #### Exercise 2: What is a program?

# %% [markdown]
# A sequence of statements (using a code language) made do do something.

# %% [markdown]
# #### Exercise 3: What is the difference between a compiler and an interpreter?

# %% [markdown]
# A compiler needs to have a whole program ready and executes it line by line, where as an interpreter is more interactive.

# %% [markdown]
# #### Exercise 4: Which of the following contains “machine code”?
#
# - a) The Python interpreter
# - b) The keyboard
# - c) Python source file
# - d) A word processing document

# %% [markdown]
# a) The Python interpreter

# %% [markdown]
# #### Exercise 5: What is wrong with the following code:
#
# ```python
# >>> primt 'Hello world!'
# File "<stdin>", line 1
#   primt 'Hello world!'
#                      ^
# SyntaxError: invalid syntax
# >>>

# %% [markdown]
# print is spelled wrong and it is missing ()
#
# It should be:
# ```python
# print('Hello world!')

# %% [markdown]
# #### Exercise 6: Where in the computer is a variable such as “x” stored after the following Python line finishes?
# ```python
#   x = 123
# ```
# - a) Central processing unit
# - b) Main Memory
# - c) Secondary Memory
# - d) Input Devices
# - e) Output Devices

# %% [markdown]
# b) Main Memory

# %% [markdown]
# #### Exercise 7: What will the following program print out:
#
# ```python
#   x = 43
#   x = x - 1
#   print(x)
# ```
#
# - a) 43
# - b) 42
# - c) x - 1
# - d) Error because x = x - 1 is not possible mathematically

# %% [markdown]
# b) 42

# %% [markdown]
# #### Exercise 8: Explain each of the following using an example of a human capability:
#
# ```markdown
# (1) Central processing unit
# (2) Main Memory
# (3) Secondary Memory
# (4) Input Device
# (5) Output Device
# ```
#
# For example, “What is the human equivalent to a Central Processing Unit”?

# %% [markdown]
# 1. Central processing unit: Is most like the brain, always looking for what's next
# 2. Main Memory: Most like short term memory, goes away after shutdown
# 3. Secondary Memory: Long term memory is better for this, stored until deleted
# 4. Input Device: This is probably closest to our senses, what me wee and hear
# 5. Output Device: I would say this would be like our speech or actions we take based on the info we take in. Art would be a cool example of this.
